# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 10.3.7 decimal shift map
#
# under: Ch 10 - 1D maps ("difference equations"). How to understand them, sometimes by translating techniques introduced in (continuous) differential equations
#
# $$x_{n+1} = 10 x_n  \mod(1)$$

# %% [markdown]
# a) Draw the graph of the map

# %%
# compute iteratively
si = 1.2345

s = [si]

stop = 10

while len(s) <= stop:
    s_mod = 10 * abs(s[-1]) # prepare 10x_n...
    s_next = s_mod - math.ceil(s_mod) # ... to execute the mod(1) operation
    s.append(s_next)

print(s)

# plot

fig, ax = plt.subplots()
ax.scatter(s[:stop], s[1:])
# Out:
# [1.2345, -0.6550000000000011, -0.44999999999998863, -0.5000000000001137, -0.9999999999988631, -1.1368683772161603e-11, -0.9999999998863132, -1.1368683772161603e-09, -0.9999999886313162, -1.1368683772161603e-07, -0.9999988631316228]
